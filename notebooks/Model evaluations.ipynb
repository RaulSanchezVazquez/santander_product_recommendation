# %%
# %matplotlib inline

# %%
import os 
import sys

prj_dir = os.path.abspath(os.getcwd() + '/..')
print(prj_dir)
sys.path.append(prj_dir)
# Out:
# /Users/raul.sanchez/k/santander_product_recommendation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src import config

# %%
challengers = ['item_most_popular', 'user_most_popular', 'recsysnet', 'net_multilabel', 'fact_matrix']
ndcg_all, ndcg = {}, {}
for challenger_name in challengers:
    path = os.path.join(
        config.PRJ_DIR, 
        'data/processed/ranks/{0}/ndcg.csv'.format(challenger_name))
    
    ndcg_all[challenger_name] = pd.read_csv(path)['all_prod']
    ndcg[challenger_name] = pd.read_csv(path)['prods']

ndcg = pd.DataFrame(ndcg)
ndcg_all = pd.DataFrame(ndcg_all)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))

ndcg.plot(
    marker='o',
    grid=True,
    ax=ax)

ax.set_title('Normalized Discounted Cumulative Gain\n(NDCG@10 Most Pop. Removed)')
ax.set_ylabel('NDCG')
ax.set_xlabel('Fold-id')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=5);

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))

ndcg_all.plot(
    marker='o',
    grid=True,
    ax=ax)

ax.set_title('Normalized Discounted Cumulative Gain\n(NDCG@10)')
ax.set_ylabel('NDCG')
ax.set_xlabel('Fold-id')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=5);
